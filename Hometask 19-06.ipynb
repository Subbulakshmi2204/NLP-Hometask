# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag, FreqDist

# Download required resources (Run once)
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')

# Input Text
text = "Ebi is a Python developer with experience in Machine Learning and Data Analysis."

# 1. Tokenization
tokens = word_tokenize(text)
print("Tokens:")
print(tokens)

# 2. Remove Stopwords
stop_words = set(stopwords.words('english'))
filtered = [word for word in tokens if word.lower() not in stop_words]

print("\nAfter Stopword Removal:")
print(filtered)

# 3. Stemming
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in filtered]

print("\nStemmed Words:")
print(stemmed)

# 4. Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered]

print("\nLemmatized Words:")
print(lemmatized)

# 5. POS Tagging
tags = pos_tag(lemmatized)

print("\nPOS Tags:")
print(tags)

# 6. Frequency Distribution
freq = FreqDist(lemmatized)

print("\nFrequency Distribution:")
print(freq)

print("\nWord Frequencies:")
for word, count in freq.items():
    print(word, ":", count)
# Out:
# Tokens:
# ['Ebi', 'is', 'a', 'Python', 'developer', 'with', 'experience', 'in', 'Machine', 'Learning', 'and', 'Data', 'Analysis', '.']
#
# After Stopword Removal:
# ['Ebi', 'Python', 'developer', 'experience', 'Machine', 'Learning', 'Data', 'Analysis', '.']
#
# Stemmed Words:
# ['ebi', 'python', 'develop', 'experi', 'machin', 'learn', 'data', 'analysi', '.']
#
# Lemmatized Words:
# ['Ebi', 'Python', 'developer', 'experience', 'Machine', 'Learning', 'Data', 'Analysis', '.']
#
# POS Tags:
# [('Ebi', 'NNP'), ('Python', 'NNP'), ('developer', 'NN'), ('experience', 'NN'), ('Machine', 'NNP'), ('Learning', 'NNP'), ('Data', 'NNP'), ('Analysis', 'NNP'), ('.', '.')]
#
# Frequency Distribution:
# <FreqDist with 9 samples and 9 outcomes>
#
# Word Frequencies:
# Ebi : 1
# Python : 1
# developer : 1
# experience : 1
# Machine : 1
# Learning : 1
# Data : 1
# Analysis : 1
# . : 1
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\subbu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\subbu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\subbu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\subbu\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
